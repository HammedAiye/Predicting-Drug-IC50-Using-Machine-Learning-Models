# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# ['Data Professor' YouTube channel](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2021-01-22 14:57:46--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2021-01-22 14:57:46--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’
#
# acetylcholinesteras 100%[===================>]   7.98M  46.7MB/s    in 0.2s
#
# 2021-01-22 14:57:47 (46.7 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’ saved [8363909/8363909]

# %%
df = pd.read_csv('alpha_amylase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (1289, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (1289, 153)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:26<00:00,  1.59it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001337 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 459
# [LightGBM] [Info] Number of data points in the train set: 1031, number of used features: 153
# [LightGBM] [Info] Start training from score 12.838812
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:26<00:00,  1.60it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000629 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 459
# [LightGBM] [Info] Number of data points in the train set: 1031, number of used features: 153
# [LightGBM] [Info] Start training from score 12.838812

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                        Adjusted R-Squared  \
# Model
# DecisionTreeRegressor                                0.82
# ExtraTreeRegressor                                   0.82
# ExtraTreesRegressor                                  0.82
# GaussianProcessRegressor                             0.82
# XGBRegressor                                         0.82
# RandomForestRegressor                                0.75
# BaggingRegressor                                     0.73
# HistGradientBoostingRegressor                        0.65
# LGBMRegressor                                        0.64
# MLPRegressor                                         0.50
# GradientBoostingRegressor                            0.45
# NuSVR                                                0.44
# SVR                                                  0.44
# KNeighborsRegressor                                  0.41
# TransformedTargetRegressor                           0.26
# LinearRegression                                     0.26
# Ridge                                                0.26
# RidgeCV                                              0.25
# SGDRegressor                                         0.22
# PoissonRegressor                                     0.21
# LassoCV                                              0.19
# ElasticNetCV                                         0.19
# HuberRegressor                                       0.19
# BayesianRidge                                        0.18
# LassoLarsCV                                          0.18
# LassoLarsIC                                          0.18
# OrthogonalMatchingPursuit                            0.14
# OrthogonalMatchingPursuitCV                          0.14
# GammaRegressor                                       0.12
# TweedieRegressor                                     0.12
# LarsCV                                               0.08
# LinearSVR                                            0.07
# AdaBoostRegressor                                    0.05
# Lasso                                               -0.17
# ElasticNet                                          -0.17
# DummyRegressor                                      -0.17
# LassoLars                                           -0.17
# PassiveAggressiveRegressor                          -0.82
# KernelRidge                                       -375.45
# Lars                                 -6032590543044165.00
# RANSACRegressor               -35781901786253585547264.00
#
#                                                 R-Squared            RMSE  \
# Model
# DecisionTreeRegressor                                0.85            0.28
# ExtraTreeRegressor                                   0.85            0.28
# ExtraTreesRegressor                                  0.85            0.28
# GaussianProcessRegressor                             0.85            0.28
# XGBRegressor                                         0.84            0.28
# RandomForestRegressor                                0.79            0.33
# BaggingRegressor                                     0.77            0.34
# HistGradientBoostingRegressor                        0.71            0.39
# LGBMRegressor                                        0.69            0.40
# MLPRegressor                                         0.57            0.47
# GradientBoostingRegressor                            0.53            0.49
# NuSVR                                                0.53            0.49
# SVR                                                  0.52            0.50
# KNeighborsRegressor                                  0.50            0.51
# TransformedTargetRegressor                           0.37            0.57
# LinearRegression                                     0.37            0.57
# Ridge                                                0.37            0.57
# RidgeCV                                              0.36            0.57
# SGDRegressor                                         0.34            0.58
# PoissonRegressor                                     0.33            0.59
# LassoCV                                              0.31            0.60
# ElasticNetCV                                         0.31            0.60
# HuberRegressor                                       0.31            0.60
# BayesianRidge                                        0.30            0.60
# LassoLarsCV                                          0.30            0.60
# LassoLarsIC                                          0.30            0.60
# OrthogonalMatchingPursuit                            0.27            0.61
# OrthogonalMatchingPursuitCV                          0.27            0.61
# GammaRegressor                                       0.25            0.62
# TweedieRegressor                                     0.25            0.62
# LarsCV                                               0.21            0.64
# LinearSVR                                            0.21            0.64
# AdaBoostRegressor                                    0.19            0.64
# Lasso                                                0.00            0.72
# ElasticNet                                           0.00            0.72
# DummyRegressor                                       0.00            0.72
# LassoLars                                            0.00            0.72
# PassiveAggressiveRegressor                          -0.55            0.89
# KernelRidge                                       -319.53           12.85
# Lars                                 -5136487287621100.00     51445956.90
# RANSACRegressor               -30466726084023683121152.00 125294219406.40
#
#                                Time Taken
# Model
# DecisionTreeRegressor                0.11
# ExtraTreeRegressor                   0.10
# ExtraTreesRegressor                  1.78
# GaussianProcessRegressor             0.64
# XGBRegressor                         0.26
# RandomForestRegressor                2.00
# BaggingRegressor                     0.17
# HistGradientBoostingRegressor        2.39
# LGBMRegressor                        0.19
# MLPRegressor                         2.18
# GradientBoostingRegressor            0.83
# NuSVR                                0.34
# SVR                                  0.33
# KNeighborsRegressor                  0.05
# TransformedTargetRegressor           0.04
# LinearRegression                     0.09
# Ridge                                0.03
# RidgeCV                              0.07
# SGDRegressor                         0.11
# PoissonRegressor                     0.68
# LassoCV                              4.08
# ElasticNetCV                         5.02
# HuberRegressor                       0.12
# BayesianRidge                        0.07
# LassoLarsCV                          0.14
# LassoLarsIC                          0.10
# OrthogonalMatchingPursuit            0.03
# OrthogonalMatchingPursuitCV          0.06
# GammaRegressor                       0.24
# TweedieRegressor                     0.09
# LarsCV                               0.37
# LinearSVR                            0.41
# AdaBoostRegressor                    0.39
# Lasso                                0.05
# ElasticNet                           0.03
# DummyRegressor                       0.03
# LassoLars                            0.04
# PassiveAggressiveRegressor           0.04
# KernelRidge                          0.13
# Lars                                 0.12
# RANSACRegressor                      2.35

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                                        Adjusted R-Squared  \
# Model
# GradientBoostingRegressor                                           -0.33
# HistGradientBoostingRegressor                                       -0.34
# LGBMRegressor                                                       -0.36
# NuSVR                                                               -0.37
# RandomForestRegressor                                               -0.37
# SVR                                                                 -0.37
# BaggingRegressor                                                    -0.48
# XGBRegressor                                                        -0.51
# KNeighborsRegressor                                                 -0.53
# PoissonRegressor                                                    -0.53
# BayesianRidge                                                       -0.57
# ElasticNetCV                                                        -0.58
# LassoCV                                                             -0.58
# SGDRegressor                                                        -0.59
# RidgeCV                                                             -0.59
# LassoLarsCV                                                         -0.62
# LassoLarsIC                                                         -0.63
# Ridge                                                               -0.66
# OrthogonalMatchingPursuit                                           -0.69
# OrthogonalMatchingPursuitCV                                         -0.69
# HuberRegressor                                                      -0.71
# GammaRegressor                                                      -0.71
# TweedieRegressor                                                    -0.71
# ExtraTreesRegressor                                                 -0.77
# LarsCV                                                              -0.85
# ExtraTreeRegressor                                                  -0.86
# DecisionTreeRegressor                                               -0.88
# AdaBoostRegressor                                                   -0.91
# LinearSVR                                                           -0.94
# MLPRegressor                                                        -1.31
# Lasso                                                               -1.47
# ElasticNet                                                          -1.47
# DummyRegressor                                                      -1.47
# LassoLars                                                           -1.47
# PassiveAggressiveRegressor                                          -2.66
# GaussianProcessRegressor                                          -453.71
# KernelRidge                                                       -692.47
# LinearRegression                                -185034340683288281088.00
# TransformedTargetRegressor                      -185034340683288281088.00
# RANSACRegressor                               -96270841883642099138560.00
# Lars                          -321046685289637867031025966517539831808.00
#
#                                                                 R-Squared  \
# Model
# GradientBoostingRegressor                                            0.46
# HistGradientBoostingRegressor                                        0.46
# LGBMRegressor                                                        0.45
# NuSVR                                                                0.45
# RandomForestRegressor                                                0.45
# SVR                                                                  0.45
# BaggingRegressor                                                     0.40
# XGBRegressor                                                         0.39
# KNeighborsRegressor                                                  0.38
# PoissonRegressor                                                     0.38
# BayesianRidge                                                        0.36
# ElasticNetCV                                                         0.36
# LassoCV                                                              0.36
# SGDRegressor                                                         0.36
# RidgeCV                                                              0.36
# LassoLarsCV                                                          0.34
# LassoLarsIC                                                          0.34
# Ridge                                                                0.33
# OrthogonalMatchingPursuit                                            0.32
# OrthogonalMatchingPursuitCV                                          0.32
# HuberRegressor                                                       0.31
# GammaRegressor                                                       0.31
# TweedieRegressor                                                     0.31
# ExtraTreesRegressor                                                  0.28
# LarsCV                                                               0.25
# ExtraTreeRegressor                                                   0.25
# DecisionTreeRegressor                                                0.24
# AdaBoostRegressor                                                    0.23
# LinearSVR                                                            0.21
# MLPRegressor                                                         0.06
# Lasso                                                               -0.00
# ElasticNet                                                          -0.00
# DummyRegressor                                                      -0.00
# LassoLars                                                           -0.00
# PassiveAggressiveRegressor                                          -0.48
# GaussianProcessRegressor                                          -183.01
# KernelRidge                                                       -279.62
# LinearRegression                                 -74877709848490196992.00
# TransformedTargetRegressor                       -74877709848490196992.00
# RANSACRegressor                               -38957850412057498746880.00
# Lars                          -129917724786468244116383962887866023936.00
#
#                                                 RMSE  Time Taken
# Model
# GradientBoostingRegressor                       0.56        0.70
# HistGradientBoostingRegressor                   0.57        3.28
# LGBMRegressor                                   0.57        0.17
# NuSVR                                           0.57        0.23
# RandomForestRegressor                           0.57        1.99
# SVR                                             0.57        0.33
# BaggingRegressor                                0.59        0.15
# XGBRegressor                                    0.60        0.61
# KNeighborsRegressor                             0.60        0.03
# PoissonRegressor                                0.61        0.25
# BayesianRidge                                   0.61        0.08
# ElasticNetCV                                    0.61        5.06
# LassoCV                                         0.62        4.02
# SGDRegressor                                    0.62        0.11
# RidgeCV                                         0.62        0.12
# LassoLarsCV                                     0.62        0.14
# LassoLarsIC                                     0.62        0.08
# Ridge                                           0.63        0.04
# OrthogonalMatchingPursuit                       0.64        0.03
# OrthogonalMatchingPursuitCV                     0.64        0.05
# HuberRegressor                                  0.64        0.12
# GammaRegressor                                  0.64        0.38
# TweedieRegressor                                0.64        0.38
# ExtraTreesRegressor                             0.65        1.80
# LarsCV                                          0.66        0.39
# ExtraTreeRegressor                              0.67        0.05
# DecisionTreeRegressor                           0.67        0.11
# AdaBoostRegressor                               0.68        0.34
# LinearSVR                                       0.68        0.40
# MLPRegressor                                    0.74        2.20
# Lasso                                           0.77        0.03
# ElasticNet                                      0.77        0.03
# DummyRegressor                                  0.77        0.03
# LassoLars                                       0.77        0.06
# PassiveAggressiveRegressor                      0.94        0.04
# GaussianProcessRegressor                       10.43        0.36
# KernelRidge                                    12.87        0.10
# LinearRegression                       6650291343.71        0.08
# TransformedTargetRegressor             6650291343.71        0.06
# RANSACRegressor                      151691724343.48        1.55
# Lars                          8759888906882902016.00        0.13

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
