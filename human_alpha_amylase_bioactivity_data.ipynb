# %% [markdown]
# <a href="https://colab.research.google.com/github/HammedAiye/Computational_Drug_Design_Cancer/blob/main/human_alpha_amylase_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('GLUT1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P11166', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'P11167', 'xref_name': None, 'xre...  Rattus norvegicus
#
#                                            pref_name  score  \
# 0                                Glucose transporter   19.0
# 1  Solute carrier family 2, facilitated glucose t...   19.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL2535
# 1               False       CHEMBL5214
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P11166', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'P11167', 'component_descriptio...  SINGLE PROTEIN   10116

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2535'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     10957315                  []
# 1        None             None     10957316                  []
# 2        None             None     13857756                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2061377  Inhibition of GLUT1 mediated [3H]-2-DG uptake ...
# 1   CHEMBL2061377  Inhibition of GLUT1 mediated [3H]-2-DG uptake ...
# 2   CHEMBL3095124  Inhibition of GLUT1 in human H1299 cells asses...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism     target_pref_name target_tax_id text_value  toid  type  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 739
# -rw------- 1 root root 755813 May  7 22:16 bioactivity_data.csv

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1318                                               None             None
# 1319  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1320                                               None             None
# 1321  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1322                                               None             None
#
#       activity_id                                activity_properties  \
# ...

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2057965   CCC(CC)CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O
# 1         CHEMBL2058262  CC(CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O)(...
# 2          CHEMBL479638               C/C(=N\O)c1ccc(-c2ccc(O)cc2)c(Cl)c1O
# 3          CHEMBL479837             COc1ccc(-c2ccc(/C(C)=N/O)c(O)c2Cl)cc1F
# 4          CHEMBL480612                   COc1ccc(-c2ccc(O)c(/C=N/O)c2)cc1
# ...                 ...                                                ...
# 1318      CHEMBL3092944      O=C(Oc1cccc(F)c1OC(=O)c1cccc(O)c1)c1cccc(O)c1
# 1319      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1320      CHEMBL4552180  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1321      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1322      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
#
#      bioactivity_class standard_value
# ...

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2057965   CCC(CC)CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O
# 1         CHEMBL2058262  CC(CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O)(...
# 2          CHEMBL479638               C/C(=N\O)c1ccc(-c2ccc(O)cc2)c(Cl)c1O
# 3          CHEMBL479837             COc1ccc(-c2ccc(/C(C)=N/O)c(O)c2Cl)cc1F
# 4          CHEMBL480612                   COc1ccc(-c2ccc(O)c(/C=N/O)c2)cc1
# ...                 ...                                                ...
# 1318      CHEMBL3092944      O=C(Oc1cccc(F)c1OC(=O)c1cccc(O)c1)c1cccc(O)c1
# 1319      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1320      CHEMBL4552180  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1321      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1322      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
#
#      standard_value
# 0            5000.0
# 1            2000.0
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2057965   CCC(CC)CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O
# 1         CHEMBL2058262  CC(CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O)(...
# 2          CHEMBL479638               C/C(=N\O)c1ccc(-c2ccc(O)cc2)c(Cl)c1O
# 3          CHEMBL479837             COc1ccc(-c2ccc(/C(C)=N/O)c(O)c2Cl)cc1F
# 4          CHEMBL480612                   COc1ccc(-c2ccc(O)c(/C=N/O)c2)cc1
# ...                 ...                                                ...
# 1318      CHEMBL3092944      O=C(Oc1cccc(F)c1OC(=O)c1cccc(O)c1)c1cccc(O)c1
# 1319      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1320      CHEMBL4552180  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1321      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1322      CHEMBL4448899  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
#
#      standard_value             0
# ...

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 856
# -rw-r--r-- 1 root root 755813 May  7 22:13 bioactivity_data.csv
# -rw-r--r-- 1 root root 107504 May  7 22:24 bioactivity_preprocessed_data.csv
# drwx------ 6 root root   4096 May  7 22:14 gdrive
# drwxr-xr-x 1 root root   4096 May  6 13:19 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
