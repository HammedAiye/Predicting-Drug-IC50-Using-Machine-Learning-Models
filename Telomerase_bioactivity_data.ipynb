# %% [markdown]
# <a href="https://colab.research.google.com/github/HammedAiye/python_project/blob/main/Telomerase_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.3 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('telomerase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'O14746', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                 []  Rattus norvegicus
# 2                                                 []       Homo sapiens
#
#                           pref_name  score  species_group_flag  \
# 0  Telomerase reverse transcriptase   22.0               False
# 1  Telomerase reverse transcriptase   22.0               False
# 2        Prostaglandin E synthase 3   13.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL2916  [{'accession': 'O14746', 'component_descriptio...
# 1    CHEMBL3108654  [{'accession': 'Q673L6', 'component_descriptio...
# 2    CHEMBL3341580  [{'accession': 'Q15185', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN    9606
# 1  SINGLE PROTEIN   10116
# 2  SINGLE PROTEIN    9606

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2916'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       106658                  []
# 1        None             None       106659                  []
# 2        None             None       107796                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL813598  Inhibitory activity against telomerase extract...
# 1    CHEMBL813598  Inhibitory activity against telomerase extract...
# 2    CHEMBL813598  Inhibitory activity against telomerase extract...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism                  target_pref_name target_tax_id text_value  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data_telomerase"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data_telomerase"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data_telomerase"
# Out:
# total 492
# -rw------- 1 root root 503413 May  6 00:59 bioactivity_data.csv

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 957  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 958  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 959  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 960  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 961  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL314057  CCN(CC)CC.O=C(N[C@H](Cc1c[nH]c2ccccc12)C(=O)NC...
# 1         CHEMBL266842  CC(C)(C)OC(=O)N[C@H](Cc1cc2ccccc2[nH]1)C(=O)N[...
# 2         CHEMBL314847  CC(C)(C)OC(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)NC...
# 3          CHEMBL86984  CC(C)(C)OC(=O)N1CCC[C@@H]1C(=O)N[C@H](Cc1c[nH]...
# 4          CHEMBL87554  CCN(CC)CC.N[C@H](Cc1cc2ccccc2[nH]1)C(=O)N[C@H]...
# ..                 ...                                                ...
# 928      CHEMBL5288791  Nc1nc(-c2cccc(OS(=O)(=O)c3ccccc3)c2)nc2c1c(=O)...
# 929      CHEMBL5287988  Nc1nc(-c2cccc(OS(=O)(=O)c3ccc([N+](=O)[O-])cc3...
# 930      CHEMBL5280294  CN(C)c1ccc(S(=O)(=O)Oc2cccc(-c3nc(N)c4c(=O)oc5...
# 931      CHEMBL5273293  COc1ccc(S(=O)(=O)Oc2cccc(-c3nc(N)c4c(=O)oc5ccc...
# 932       CHEMBL284328   CC[n+]1c(-c2ccccc2)c2cc(N)ccc2c2ccc(N)cc21.[Br-]
#
#     bioactivity_class standard_value
# 0        intermediate         7300.0
# ...

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL314057  CCN(CC)CC.O=C(N[C@H](Cc1c[nH]c2ccccc12)C(=O)NC...
# 1         CHEMBL266842  CC(C)(C)OC(=O)N[C@H](Cc1cc2ccccc2[nH]1)C(=O)N[...
# 2         CHEMBL314847  CC(C)(C)OC(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)NC...
# 3          CHEMBL86984  CC(C)(C)OC(=O)N1CCC[C@@H]1C(=O)N[C@H](Cc1c[nH]...
# 4          CHEMBL87554  CCN(CC)CC.N[C@H](Cc1cc2ccccc2[nH]1)C(=O)N[C@H]...
# ..                 ...                                                ...
# 957      CHEMBL5288791  Nc1nc(-c2cccc(OS(=O)(=O)c3ccccc3)c2)nc2c1c(=O)...
# 958      CHEMBL5287988  Nc1nc(-c2cccc(OS(=O)(=O)c3ccc([N+](=O)[O-])cc3...
# 959      CHEMBL5280294  CN(C)c1ccc(S(=O)(=O)Oc2cccc(-c3nc(N)c4c(=O)oc5...
# 960      CHEMBL5273293  COc1ccc(S(=O)(=O)Oc2cccc(-c3nc(N)c4c(=O)oc5ccc...
# 961       CHEMBL284328   CC[n+]1c(-c2ccccc2)c2cc(N)ccc2c2ccc(N)cc21.[Br-]
#
#     standard_value
# 0           7300.0
# 1         100000.0
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL314057  CCN(CC)CC.O=C(N[C@H](Cc1c[nH]c2ccccc12)C(=O)NC...
# 1         CHEMBL266842  CC(C)(C)OC(=O)N[C@H](Cc1cc2ccccc2[nH]1)C(=O)N[...
# 2         CHEMBL314847  CC(C)(C)OC(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)NC...
# 3          CHEMBL86984  CC(C)(C)OC(=O)N1CCC[C@@H]1C(=O)N[C@H](Cc1c[nH]...
# 4          CHEMBL87554  CCN(CC)CC.N[C@H](Cc1cc2ccccc2[nH]1)C(=O)N[C@H]...
# ..                 ...                                                ...
# 369                NaN                                                NaN
# 370                NaN                                                NaN
# 371                NaN                                                NaN
# 455                NaN                                                NaN
# 456                NaN                                                NaN
#
#     standard_value             0
# 0           7300.0  intermediate
# ...

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 576
# -rw-r--r-- 1 root root 503413 May  6 00:56 bioactivity_data.csv
# -rw-r--r-- 1 root root  77221 May  6 01:05 bioactivity_preprocessed_data.csv
# drwx------ 6 root root   4096 May  6 00:57 gdrive
# drwxr-xr-x 1 root root   4096 May  2 13:25 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data_telomerase"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data_telomerase"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
