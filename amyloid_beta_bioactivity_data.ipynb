# %% [markdown]
# <a href="https://colab.research.google.com/github/HammedAiye/Computational_Drug_Design/blob/main/amyloid_beta_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for amyloid beta A4 protein
target = new_client.target
target_query = target.search('amyloid-beta')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references           organism  \
# 0     [{'xref_id': 'P05067', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                    []  Rattus norvegicus
# 2                                                    []       Mus musculus
# 3                                                    []       Homo sapiens
# 4     [{'xref_id': 'P37840', 'xref_name': None, 'xre...       Homo sapiens
# ...                                                 ...                ...
# 1313                                                 []       Homo sapiens
# 1314                                                 []       Homo sapiens
# 1315                                                 []       Homo sapiens
# 1316                                                 []       Homo sapiens
# 1317                                                 []           Bacteria
#
#                                           pref_name  score  \
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2487'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-10-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1598  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1599  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1600  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1601  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1188

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1598  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1599  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1600  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1601  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1602  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1598      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1599      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1600      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1601      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1602      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#      standard_value
# 0            5000.0
# 1            2700.0
# ...

# %%
df3.to_csv('amyloid_beta_02_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('amyloid_beta_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL311039          CC12CCC(C1)C(C)(C)C2NS(=O)(=O)c1ccc(F)cc1
# 1          CHEMBL450926    CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1cccs1
# 2          CHEMBL310242  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 3           CHEMBL74874  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# 4           CHEMBL75183  CC12CC[C@@H](C1)C(C)(C)[C@@H]2NS(=O)(=O)c1ccc(...
# ...                 ...                                                ...
# 1183      CHEMBL5274298  COC(=O)c1cc(O)cc(OC)c1C(=O)c1c(O)cc(CO[C@H]2O[...
# 1184      CHEMBL5283067  COC(=O)c1c(Sc2c(O)cc(OC)c(C(=O)c3c(O)cc(C)cc3O...
# 1185      CHEMBL5273520  COC(=O)c1c(O)cc(C)c(Sc2c(O)cc(OC)c(Oc3c(O)cc(C...
# 1186      CHEMBL5282081  COC(=O)c1c(O)cc(C)cc1C(=O)c1cc(O)cc2oc3cc4c(c(...
# 1187      CHEMBL5274654  Cc1cc(O)c(C(=O)c2c(O)cc3c(c2O)C(=O)c2c(O)cc(C)...
#
#       standard_value         class
# ...

# %%
df5.to_csv('amyloid_beta_03_bioactivity_data_curated.csv', index=False)

# %%
! zip amyloid_beta.zip *.csv
# Out:
#   adding: amyloid_beta_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: amyloid_beta_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 272
# -rw-r--r-- 1 root root  36775 Jun  8 08:23 alpha_amylase.zip
# -rw-r--r-- 1 root root  92019 Jun  8 08:20 amyloid_beta_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 103151 Jun  8 08:23 amyloid_beta_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  36775 Jun  8 08:23 amyloid_beta.zip
# drwxr-xr-x 1 root root   4096 Jun  6 14:21 sample_data
