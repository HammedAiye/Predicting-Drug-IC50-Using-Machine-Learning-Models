# %% [markdown]
# <a href="https://colab.research.google.com/github/HammedAiye/Computational_Drug_Design_Cancer/blob/main/alpha_amylase_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bioinformatics Project - Computational Drug Discovery

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 694.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('GLUT1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P11166', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'P11167', 'xref_name': None, 'xre...  Rattus norvegicus
#
#                                            pref_name  score  \
# 0                                Glucose transporter   19.0
# 1  Solute carrier family 2, facilitated glucose t...   19.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL2535
# 1               False       CHEMBL5214
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P11166', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'P11167', 'component_descriptio...  SINGLE PROTEIN   10116

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2535'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1318                                               None             None
# 1319  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1320                                               None             None
# 1321  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1322                                               None             None
#
#       activity_id                                activity_properties  \
# ...

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1318                                               None             None
# 1319  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1320                                               None             None
# 1321  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1322                                               None             None
#
#       activity_id                                activity_properties  \
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1289

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1310  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1313                                               None       Not Active
# 1314                                               None           Active
# 1315                                               None       Not Active
# 1317  {'action_type': 'INHIBITOR', 'description': 'N...        Inhibitor
#
#       activity_id                                activity_properties  \
# ...

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2057965   CCC(CC)CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O
# 1         CHEMBL2058262  CC(CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O)(...
# 2          CHEMBL479638               C/C(=N\O)c1ccc(-c2ccc(O)cc2)c(Cl)c1O
# 3          CHEMBL479837             COc1ccc(-c2ccc(/C(C)=N/O)c(O)c2Cl)cc1F
# 4          CHEMBL480612                   COc1ccc(-c2ccc(O)c(/C=N/O)c2)cc1
# ...                 ...                                                ...
# 1310      CHEMBL4786111  O=C(CN1C(=O)S/C(=C/c2ccco2)C1=O)Nc1ccc(Cl)c(Cl)c1
# 1313      CHEMBL4552180  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1314      CHEMBL4445670  CN1CCN(c2cnc3c(C4CCN(C(=O)c5ccc(OC(F)(F)F)cc5N...
# 1315      CHEMBL4455582  Cc1nc(C2CCN(C(=O)c3ccc(OC(F)(F)F)cc3N)CC2)c2nc...
# 1317       CHEMBL411729  C=C1[C@@H](C)[C@H]2[C@H](Cc3ccccc3)NC(=O)[C@]2...
#
#      standard_value
# 0            5000.0
# 1            2000.0
# ...

# %%
df3.to_csv('alpha_amylase_02_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('alpha_amylase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2057965   CCC(CC)CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O
# 1         CHEMBL2058262  CC(CN1C(=O)S/C(=C\c2ccc(O)c(C(F)(F)F)c2)C1=O)(...
# 2          CHEMBL479638               C/C(=N\O)c1ccc(-c2ccc(O)cc2)c(Cl)c1O
# 3          CHEMBL479837             COc1ccc(-c2ccc(/C(C)=N/O)c(O)c2Cl)cc1F
# 4          CHEMBL480612                   COc1ccc(-c2ccc(O)c(/C=N/O)c2)cc1
# ...                 ...                                                ...
# 1284      CHEMBL4786111  O=C(CN1C(=O)S/C(=C/c2ccco2)C1=O)Nc1ccc(Cl)c(Cl)c1
# 1285      CHEMBL4552180  Cc1c(NC(=O)c2cc(C(N)=O)nc3cc(F)ccc23)c(C(F)(F)...
# 1286      CHEMBL4445670  CN1CCN(c2cnc3c(C4CCN(C(=O)c5ccc(OC(F)(F)F)cc5N...
# 1287      CHEMBL4455582  Cc1nc(C2CCN(C(=O)c3ccc(OC(F)(F)F)cc3N)CC2)c2nc...
# 1288       CHEMBL411729  C=C1[C@@H](C)[C@H]2[C@H](Cc3ccccc3)NC(=O)[C@]2...
#
#       standard_value         class
# ...

# %%
df5.to_csv('alpha_amylase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip alpha_amylase.zip *.csv
# Out:
#   adding: alpha_amylase_02_bioactivity_data_preprocessed.csv (deflated 79%)
#   adding: alpha_amylase_03_bioactivity_data_curated.csv (deflated 81%)

# %%
! ls -l
# Out:
# total 252
# -rw-r--r-- 1 root root  96382 May  8 06:36 alpha_amylase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 108895 May  8 06:39 alpha_amylase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  41902 May  8 06:40 alpha_amylase.zip
# drwxr-xr-x 1 root root   4096 May  6 13:19 sample_data
