# %% [markdown]
# <a href="https://colab.research.google.com/github/HammedAiye/Computational_Drug_Design_Cancer/blob/main/alpha-amylase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 753.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('alpha-amylase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references  \
# 0     [{'xref_id': 'P04745', 'xref_name': None, 'xre...
# 1     [{'xref_id': 'P94451', 'xref_name': None, 'xre...
# 2                                                    []
# 3                                                    []
# 4     [{'xref_id': 'P21567', 'xref_name': None, 'xre...
# ...                                                 ...
# 1450                                                 []
# 1451                                                 []
# 1452                                                 []
# 1453                                                 []
# 1454                                                 []
#
#                             organism  \
# 0                       Homo sapiens
# 1     Geobacillus stearothermophilus
# 2              Sus scrofa domesticus
# 3                    Hordeum vulgare
# 4        Saccharomycopsis fibuligera
# ...                              ...
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2478'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      2347277                  []
# 1        None   Not Determined      2347279                  []
# 2        None   Not Determined      2347281                  []
#
#   assay_chembl_id                           assay_description assay_type  \
# 0    CHEMBL964479  Inhibition of human salivary alpha-amylase          B
# 1    CHEMBL964479  Inhibition of human salivary alpha-amylase          B
# 2    CHEMBL964479  Inhibition of human salivary alpha-amylase          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism        target_pref_name target_tax_id text_value  toid  \
# ...

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None      2347277                  []
# 13        None             None      2347303                  []
# 14        None             None      2347305                  []
# 15        None             None      2347307                  []
# 16        None             None      2347309                  []
# 17        None             None      2347311                  []
# 18        None             None      2347937                  []
# 19        None             None      2347939                  []
# 20        None             None     15725517                  []
# 22        None             None     15725519                  []
# 23        None             None     15725520                  []
# 24        None             None     15725521                  []
# 25        None             None     15725522                  []
# ...

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  #else:
  #  bioactivity_class.append("intermediate")

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL1566  C[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](O...
# 13       CHEMBL172350          COc1c(O)cc2oc(-c3ccc(O)c(O)c3)cc(=O)c2c1O
# 14          CHEMBL151            O=c1cc(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12
# 15        CHEMBL55415            O=c1cc(-c2ccc(O)cc2)oc2cc(O)c(O)c(O)c12
# 16          CHEMBL164      O=c1c(O)c(-c2cc(O)c(O)c(O)c2)oc2cc(O)cc(O)c12
# 17       CHEMBL413552      O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)c(O)c(O)c12
# 18        CHEMBL31574            O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)ccc12
# 19           CHEMBL50         O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12
# 20         CHEMBL1566  C[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](O...
# 22       CHEMBL559070                 Oc1ccc(Nc2nc(-c3ccc(O)cc3O)cs2)cc1
# 23      CHEMBL1904421         Cc1ccc(O)c(Cc2cc(C)cc(Cc3cc(C)ccc3O)c2O)c1
# 24      CHEMBL3618478  COc1cccc(C2NC(c3cccc(OC)c3O)C([N+](=O)[O-])C(C...
# ...

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL1566  C[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](O...
# 13       CHEMBL172350          COc1c(O)cc2oc(-c3ccc(O)c(O)c3)cc(=O)c2c1O
# 14          CHEMBL151            O=c1cc(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12
# 15        CHEMBL55415            O=c1cc(-c2ccc(O)cc2)oc2cc(O)c(O)c(O)c12
# 16          CHEMBL164      O=c1c(O)c(-c2cc(O)c(O)c(O)c2)oc2cc(O)cc(O)c12
# 17       CHEMBL413552      O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)c(O)c(O)c12
# 18        CHEMBL31574            O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)ccc12
# 19           CHEMBL50         O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12
# 20         CHEMBL1566  C[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](O...
# 22       CHEMBL559070                 Oc1ccc(Nc2nc(-c3ccc(O)cc3O)cs2)cc1
# 23      CHEMBL1904421         Cc1ccc(O)c(Cc2cc(C)cc(Cc3cc(C)ccc3O)c2O)c1
# 24      CHEMBL3618478  COc1cccc(C2NC(c3cccc(OC)c3O)C([N+](=O)[O-])C(C...
# ...

# %%
df4.to_csv('bioactivity_data_preprocessed.csv', index=False)

# %%
! ls -l
# Out:
# total 32
# -rw-r--r-- 1 root root  3023 May  6 10:12 bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 23444 May  6 10:11 bioactivity_data_raw.csv
# drwxr-xr-x 1 root root  4096 May  2 13:25 sample_data
